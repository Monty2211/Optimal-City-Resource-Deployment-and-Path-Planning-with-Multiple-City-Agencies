# %%
import osmnx as ox
import matplotlib.pyplot as plt 
import osmnx as ox
import pandas as pd
from geopy import distance
import requests # to call the openmap/google apis
import json
import datetime
import math
import itertools
import numpy as np
import networkx as nx
import osmnx as ox
from shapely.geometry import Point, LineString
import plotly_express as px
import pandas as pd
import geopandas as gpd

# %%
ox.config(use_cache=True, log_console=True) #For debugging
# Out:
# 2021-09-25 21:30:36 Configured OSMnx 1.1.1
# 2021-09-25 21:30:36 HTTP response caching is on

# %%
def create_rochester_graph(loc, dist, transport_mode, loc_type="address"):
    """Transport mode = ‘walk’, ‘bike’, ‘drive’, ‘drive_service’, ‘all’, ‘all_private’, ‘none’"""
    if loc_type == "address":
        roc_graph = ox.graph_from_address(loc, dist=dist, network_type=transport_mode)
    elif loc_type == "points":
        roc_graph = ox.graph_from_point(loc, dist=dist, network_type=transport_mode )
    return roc_graph

# %%
roc_graph = create_rochester_graph('Rochester', 2500, 'drive_service')
ox.plot_graph(roc_graph)
# Out:
# 2021-09-25 21:30:36 Retrieved response from cache file "cache/122893a9c77ace471118d977e4561a9f45117fb9.json"
# 2021-09-25 21:30:36 Geocoded "Rochester" to (43.157285, -77.615214)
# 2021-09-25 21:30:36 Created bbox 2500 m from (43.157285, -77.615214): 43.17976800838733,43.134801991612676,-77.58439335186361,-77.64603464813638
# 2021-09-25 21:30:36 Projected GeoDataFrame to +proj=utm +zone=18 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-09-25 21:30:36 Projected GeoDataFrame to epsg:4326
# 2021-09-25 21:30:36 Projected GeoDataFrame to +proj=utm +zone=18 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-09-25 21:30:37 Projected GeoDataFrame to epsg:4326
# 2021-09-25 21:30:37 Requesting data within polygon from API in 1 request(s)
# 2021-09-25 21:30:37 Retrieved response from cache file "cache/66eb9a81695e56cf27dbddcfd75fd7d9ad62f64d.json"
# 2021-09-25 21:30:37 Got all network data within polygon from API in 1 request(s)
# 2021-09-25 21:30:37 Creating graph from downloaded OSM data...
# 2021-09-25 21:30:37 Created graph with 19364 nodes and 35957 edges
# 2021-09-25 21:30:37 Added length attributes to graph edges
# 2021-09-25 21:30:37 Identifying all nodes that lie outside the polygon...
# 2021-09-25 21:30:38 Created nodes GeoDataFrame from graph
# 2021-09-25 21:30:38 Created r-tree spatial index for 19364 geometries
# 2021-09-25 21:30:38 Identified 18114 geometries inside polygon
# 2021-09-25 21:30:39 Removed 1250 nodes outside polygon
# 2021-09-25 21:30:39 Truncated graph by polygon
# 2021-09-25 21:30:39 Begin topologically simplifying the graph...
# 2021-09-25 21:30:39 Identified 5049 edge endpoints
# 2021-09-25 21:30:40 Simplified graph: 18114 to 5049 nodes, 33485 to 12979 edges
# 2021-09-25 21:30:40 Identifying all nodes that lie outside the polygon...
# 2021-09-25 21:30:40 Created nodes GeoDataFrame from graph
# 2021-09-25 21:30:40 Created r-tree spatial index for 5049 geometries
# 2021-09-25 21:30:40 Identified 3971 geometries inside polygon
# 2021-09-25 21:30:40 Removed 1078 nodes outside polygon
# 2021-09-25 21:30:40 Removed 3 isolated nodes
# 2021-09-25 21:30:40 Got largest weakly connected component (3932 of 3968 total nodes)
# 2021-09-25 21:30:40 Truncated graph by polygon
# 2021-09-25 21:30:41 Counted undirected street segments incident on each node
# 2021-09-25 21:30:41 graph_from_polygon returned graph with 3932 nodes and 10029 edges
# 2021-09-25 21:30:41 graph_from_bbox returned graph with 3932 nodes and 10029 edges
# 2021-09-25 21:30:41 graph_from_point returned graph with 3932 nodes and 10029 edges
# 2021-09-25 21:30:41 graph_from_address returned graph with 3932 nodes and 10029 edges
# 2021-09-25 21:30:41 Begin plotting the graph...
# 2021-09-25 21:30:41 Created edges GeoDataFrame from graph
# 2021-09-25 21:30:42 Created nodes GeoDataFrame from graph
# 2021-09-25 21:30:42 Finished plotting the graph
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
roc_df = pd.read_csv("BoxAreaRochester.csv")

# %%
roc_df
# Out:
#     Unnamed: 0   Locations   Latitude  Longitude
# 0            0   212629561  43.137407 -77.598233
# 1            1   212629563  43.136945 -77.598493
# 2            2   212676319  43.134420 -77.602399
# 3            3   212769675  43.137430 -77.603818
# 4            4   212769677  43.136636 -77.601178
# 5            5   212769679  43.135769 -77.598343
# 6            6   212782003  43.138067 -77.600400
# 7            7   212782005  43.137609 -77.598897
# 8            8   212813912  43.138074 -77.603483
# 9            9   212813914  43.137271 -77.600835
# 10          10   212813917  43.136415 -77.597977
# 11          11   212872572  43.136007 -77.601529
# 12          12   212872575  43.135133 -77.598700
# 13          13   212873619  43.135553 -77.598466
# 14          14   212904187  43.134500 -77.599068
# 15          15   212908698  43.135347 -77.601880
# 16          16   212908725  43.133946 -77.603805
# 17          17  2653824864  43.136355 -77.598010
# 18          18  8077196381  43.137160 -77.598372

# %%
routes =[[(11, 4),
  (4, 7),
  (7, 0),
  (0, 18),
  (18, 1),
  (1, 6),
  (6, 9),
  (9, 8),
  (8, 3),
  (3, 11)],
 [(11, 15),
  (15, 2),
  (2, 16),
  (16, 14),
  (14, 12),
  (12, 13),
  (13, 5),
  (5, 17),
  (17, 10),
  (10, 11)]]

# %%
routes[0]
# Out:
# [(11, 4),
#  (4, 7),
#  (7, 0),
#  (0, 18),
#  (18, 1),
#  (1, 6),
#  (6, 9),
#  (9, 8),
#  (8, 3),
#  (3, 11)]

# %%
order1 = [11,4,7,0,18,1,6,9,8,3]
order2 = [11,15,2,16,14,12,13,5,17,10]

# %%
df3 = pd.DataFrame()
for i in order1:
    df3 = df3.append(roc_df.loc[i])

# %%
df4 = pd.DataFrame()
for i in order1:
    df4 = df4.append(roc_df.loc[i])

# %%
df4
# Out:
#     Unnamed: 0     Locations   Latitude  Longitude
# 11        11.0  2.128726e+08  43.136007 -77.601529
# 4          4.0  2.127697e+08  43.136636 -77.601178
# 7          7.0  2.127820e+08  43.137609 -77.598897
# 0          0.0  2.126296e+08  43.137407 -77.598233
# 18        18.0  8.077196e+09  43.137160 -77.598372
# 1          1.0  2.126296e+08  43.136945 -77.598493
# 6          6.0  2.127820e+08  43.138067 -77.600400
# 9          9.0  2.128139e+08  43.137271 -77.600835
# 8          8.0  2.128139e+08  43.138074 -77.603483
# 3          3.0  2.127697e+08  43.137430 -77.603818

# %%
df3.reset_index(inplace = True)
df4.reset_index(inplace = True)

# %%
loc=[]
for i in df4.index:
    loc.append(int(df4.loc[i]['Locations']))
loc
# Out:
# [212872572,
#  212769677,
#  212782005,
#  212629561,
#  8077196381,
#  212629563,
#  212782003,
#  212813914,
#  212813912,
#  212769675]

# %%
ox.plot_graph(roc_graph)

# %%
type(roc_graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
roc_graph[8077196381]
# Out:
# AdjacencyView({212629563: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 25.844}}, 212629561: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691}}})

# %%
loc=[]
for i in df3.index:
    print(roc_graph[df3.loc[i]['Locations']])
#roc_graph[df3.loc[0]['Locations']]
# Out:
# {212872575: {0: {'osmid': 20132618, 'name': 'Mulberry Street', 'highway': 'residential', 'oneway': False, 'length': 249.314}}, 212872569: {0: {'osmid': 20132618, 'name': 'Mulberry Street', 'highway': 'residential', 'oneway': False, 'length': 231.025}}, 212908698: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 78.722}}, 212769677: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.518}}}
# {212769675: {0: {'osmid': 20123307, 'name': 'Crawford Street', 'highway': 'residential', 'oneway': False, 'length': 231.694}}, 212872572: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.518}}, 212813914: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.896}}, 212769679: {0: {'osmid': 20123307, 'name': 'Crawford Street', 'highway': 'residential', 'oneway': False, 'length': 249.458, 'geometry': <shapely.geometry.linestring.LineString object at 0x178abc640>}}}
# {212629561: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 58.372}}, 212782003: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 132.16}}}
# {8077196381: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691}}, 212629557: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 115.935}}, 212782009: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 60.861}}, 212782005: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 58.372}}}
# {212629563: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 25.844}}, 212629561: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691}}}
# {8077196381: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 25.844}}}
# {212782005: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 132.16}}, 212782001: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 233.542}}, 212908695: {0: {'osmid': 38656179, 'name': 'Meigs Street', 'highway': 'tertiary', 'oneway': False, 'length': 115.685}}, 212813914: {0: {'osmid': 38656179, 'name': 'Meigs Street', 'highway': 'tertiary', 'oneway': False, 'length': 95.28999999999999, 'geometry': <shapely.geometry.linestring.LineString object at 0x17c03e790>}}}
# {212813912: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 232.675}}, 212769677: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.896}}, 212813917: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 250.723, 'geometry': <shapely.geometry.linestring.LineString object at 0x179397a00>}}, 212782003: {0: {'osmid': 38656179, 'name': 'Meigs Street', 'highway': 'tertiary', 'oneway': False, 'length': 95.28999999999999, 'geometry': <shapely.geometry.linestring.LineString object at 0x179397a30>}}}
# {212813914: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 232.675}}, 212772024: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 107.719}}, 212769675: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 76.595}}, 212782001: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 94.223}}}
# {212769677: {0: {'osmid': 20123307, 'name': 'Crawford Street', 'highway': 'residential', 'oneway': False, 'length': 231.694}}, 212872569: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 76.089}}, 212813912: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 76.595}}}

# %%
roc_graph[212629561]
# Out:
# AdjacencyView({8077196381: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691}}, 212629557: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 115.935}}, 212782009: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 60.861}}, 212782005: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 58.372}}})

# %%
path=[212711088,
 6863491042,
 212711081,
 6950355751,
 6950355754,
 212711079,
 8578511237,
 8578511239,
 212627933,
 8077503695,
 3665094176,
 212890741,
 5371345759,
 212630426,
 212863159,
 212663712,
 212654931,
 7302320094,
 5585330044,
 3415688712,
 391967057,
 212690367,
 212745042,
 212890690,
 212772328,
 212762363,
 212714271,
 212838342,
 212859862,
 5746222889,
 212898187,
 212757743,
 8578366709,
 212666680,
 212681097,
 5745948590,
 212685591,
 212685595,
 212631301,
 7085426685,
 212685599,
 212685602,
 6937268311,
 212685604,
 212627367,
 212685619,
 212685624,
 212685628,
 212685631,
 212685635,
 212685639,
 212685642,
 8021283011,
 212685650,
 212685653,
 212685657,
 212685660,
 212685663,
 212685666,
 212643349,
 212685670,
 212685673,
 212685678,
 212685682,
 212685686,
 212685688,
 212685691]

# %%
#ox.plot_graph_route(roc_graph, path, route_linewidth=3, node_size=0, bgcolor='k');
# Out:
# 2021-09-25 11:00:46 Begin plotting the graph...
# 2021-09-25 11:00:47 Created edges GeoDataFrame from graph
# 2021-09-25 11:00:50 Finished plotting the graph

# %%
#path1=[5762705102,212714285,2201631380]

# %%
#11 43.136007, 77.601529
#4  43.136636, 77.601178
#7  43.137609,-77.598897
#0  43.137407,-77.598233
#18 43.137160,-77.598372
#1  43.136945,-77.598493
#6  43.138067,-77.600400
#9  43.137271,-77.600835
#8  43.138074,-77.603483
#3  43.137430,-77.603818

#First Route
#[[(11, 4),(4, 7),(7, 0),(0, 18),(18, 1),(1, 6),(6, 9),(9, 8),(8, 3),(3, 11)],

#15  43.135347,-77.601880
#2   43.134420,-77.602399
#16  43.133946,-77.603805
#14  43.134500, -77.599068
#12  43.135133, -77.598700
#13  43.135553, -77.598466
#5   43.135769, -77.598343
#17  43.136355, -77.598010
#10  43.136415, -77.597977


#Second Route
#[(11, 15),(15, 2),(2, 16),(16, 14),(14, 12),(12, 13),(13, 5),(5, 17),(17, 10),(10, 11)]]

# %%
paths=[]
#11-4
roc_graph = ox.add_edge_speeds(roc_graph) #Impute
roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
source = (43.136007, -77.601529) #Highland Park
destination = (43.136636, -77.601178)   #West Irondequoit
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]


#4-7
source = (43.136636, -77.601178)
destination = (43.137609, -77.598897) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]

#7-0
source = (43.137609, -77.598897)
destination = (43.137407, -77.598233) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]


#0-18
source = (43.137407, -77.598233) 
destination = (43.137160,-77.598372) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]


#18-1
source = (43.137160,-77.598372)
destination = (43.136945,-77.598493) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]


#1-6
source = (43.136945,-77.598493)
destination = (43.138067,-77.600400) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]


#6-9
source = (43.138067,-77.600400)
destination = (43.137271,-77.600835) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]



#9-8
source = (43.137271,-77.600835)
destination = (43.138074,-77.603483) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[-1]


#8-3
source = (43.138074,-77.603483)
destination = (43.137430,-77.603818) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
#del paths[-1]


paths.append(path)

#Plot the route and street networks
ox.plot_graph_route(roc_graph, paths[0], route_linewidth=3, node_size=0, bgcolor='k');
# Out:
# 2021-09-25 23:04:59 Created edges GeoDataFrame from graph
# 2021-09-25 23:05:01 Created edges GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Created nodes GeoDataFrame from graph
# 2021-09-25 23:05:02 Begin plotting the graph...
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:05:03 Created edges GeoDataFrame from graph
# 2021-09-25 23:05:07 Finished plotting the graph

# %%
del paths[0][-1]
paths
# Out:
# [[212872572]]

# %%
paths=[]
#11-4
roc_graph = ox.add_edge_speeds(roc_graph) #Impute
roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
source = (43.136007, -77.601529) #Highland Park
destination = (43.136636, -77.601178)   #West Irondequoit
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[0][-1]


#4-7
paths2=[]
source = (43.136636, -77.601178)
destination = (43.137609, -77.598897) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths2.append(path)
del paths2[0][-1]

#7-0
paths3=[]
source = (43.137609, -77.598897)
destination = (43.137407, -77.598233) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths3.append(path)
del paths3[0][-1]


#0-18
paths4=[]
source = (43.137407, -77.598233) 
destination = (43.137160,-77.598372) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths4.append(path)
del paths4[0][-1]


#18-1
paths5=[]
source = (43.137160,-77.598372)
destination = (43.136945,-77.598493) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths5.append(path)
del paths5[0][-1]


#1-6
paths6=[]
source = (43.136945,-77.598493)
destination = (43.138067,-77.600400) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths6.append(path)
del paths6[0][-1]


#6-9
paths7=[]
source = (43.138067,-77.600400)
destination = (43.137271,-77.600835) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths7.append(path)
del paths7[0][-1]



#9-8
paths8=[]
source = (43.137271,-77.600835)
destination = (43.138074,-77.603483) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths8.append(path)
del paths8[0][-1]


#8-3
paths9=[]
source = (43.138074,-77.603483)
destination = (43.137430,-77.603818) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths9.append(path)
#del paths[-1]




final=[]
final=paths+paths2+paths3+paths4+paths5+paths6+paths7+paths8+paths9
final_a=final[0]+final[1]+final[2]+final[3]+final[4]+final[5]+final[6]+final[7]+final[8]

#Plot the route and street networks
ox.plot_graph_route(roc_graph, final_a, route_linewidth=3, node_size=0, bgcolor='k');
# Out:
# 2021-09-25 23:36:58 Created edges GeoDataFrame from graph
# 2021-09-25 23:37:00 Created edges GeoDataFrame from graph
# 2021-09-25 23:37:00 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:00 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:37:00 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:00 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:00 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# 2021-09-25 23:37:01 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:37:01 Begin plotting the graph...
# 2021-09-25 23:37:02 Created edges GeoDataFrame from graph
# 2021-09-25 23:37:05 Finished plotting the graph

# %%
p=[]
#Second Route-
roc_graph = ox.add_edge_speeds(roc_graph) #Impute
roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
#11-15
source = (43.136007, -77.601529)
destination = (43.135347,-77.601880) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p.append(path)
del p[0][-1]

#15-2
p2=[]
source = (43.135347,-77.601880)
destination = (43.134420,-77.602399) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p2.append(path)
del p2[0][-1]


#2-16
p3=[]
source = (43.134420,-77.602399)
destination = (43.133946,-77.603805) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p3.append(path)
del p3[0][-1]


#16-14
p4=[]
source = (43.133946,-77.603805)
destination = (43.134500, -77.599068) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p4.append(path)
del p4[0][-1]


#14-12
p5=[]
source = (43.134500, -77.599068)
destination = (43.135133, -77.598700) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p5.append(path)
del p5[0][-1]


#12-13
p6=[]
source = (43.135133, -77.598700)
destination = (43.135553, -77.598466) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p6.append(path)
del p6[0][-1]


#13-5
p7=[]
source = (43.135553, -77.598466)
destination = (43.135769, -77.598343) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p7.append(path)
del p7[0][-1]


#5-17
p8=[]
source = (43.135769, -77.598343)
destination = (43.136355, -77.598010) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p8.append(path)
del p8[0][-1]


#17-10
p9=[]
source = (43.136355, -77.598010)
destination = (43.136415, -77.597977) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
p9.append(path)



final_p=[]
final_p=p+p2+p3+p4+p5+p6+p7+p8+p9
final_path=final_p[0]+final_p[1]+final_p[2]+final_p[3]+final_p[4]+final_p[5]+final_p[6]+final_p[7]+final_p[8]

#Plot the route and street networks
ox.plot_graph_route(roc_graph, final_path, route_linewidth=3, node_size=0, bgcolor='k');
# Out:
# 2021-09-25 23:46:06 Created edges GeoDataFrame from graph
# 2021-09-25 23:46:07 Created edges GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:07 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:08 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:08 Created nodes GeoDataFrame from graph
# 2021-09-25 23:46:08 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:46:08 Begin plotting the graph...
# 2021-09-25 23:46:09 Created edges GeoDataFrame from graph
# 2021-09-25 23:46:12 Finished plotting the graph

# %%
paths=[]
#11-4
roc_graph = ox.add_edge_speeds(roc_graph) #Impute
roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
source = (43.136007, -77.601529) #Highland Park
destination = (43.136636, -77.601178)   #West Irondequoit
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths.append(path)
del paths[0][-1]


#4-7
paths2=[]
source = (43.136636, -77.601178)
destination = (43.137609, -77.598897) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths2.append(path)

final=[]
final=paths+paths2
final_a=final[0]+final[1]

#Plot the route and street networks
ox.plot_graph_route(roc_graph, final_a, route_linewidth=3, node_size=0, bgcolor='k');

# %%
final
# Out:
# [[212872572], [212769677, 212813914, 212782003, 212782005]]

# %%
paths
# Out:
# [[212872572, 212769677], [212769677, 212813914, 212782003, 212782005]]

# %%
final=[212872572,212769677,212813914, 212782003, 212782005]

# %%
paths3=paths[0]+paths[1]
paths3
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/0f/0wx77bhd2sl15rhs858yxhtc0000gn/T/ipykernel_21510/1018896769.py in <module>
# ----> 1 paths3=paths[0]+paths[1]
#       2 paths3
#
# IndexError: list index out of range

# %%
paths1 = []
#Second Route-
roc_graph = ox.add_edge_speeds(roc_graph) #Impute
roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
#11-15
source = (43.136007, -77.601529)
destination = (43.135347,-77.601880) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]

#15-2
source = (43.135347,-77.601880)
destination = (43.134420,-77.602399) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#2-16
source = (43.134420,-77.602399)
destination = (43.133946,-77.603805) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#16-14
source = (43.133946,-77.603805)
destination = (43.134500, -77.599068) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#14-12
source = (43.134500, -77.599068)
destination = (43.135133, -77.598700) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#12-13
source = (43.135133, -77.598700)
destination = (43.135553, -77.598466) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#13-5
source = (43.135553, -77.598466)
destination = (43.135769, -77.598343) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#5-17
source = (43.135769, -77.598343)
destination = (43.136355, -77.598010) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]


#17-10
source = (43.136355, -77.598010)
destination = (43.136415, -77.597977) 
   
source_node = ox.get_nearest_node(roc_graph, source)
destination_node = ox.get_nearest_node(roc_graph, destination)
# Calculate the shortest path
path = nx.shortest_path(roc_graph, source_node, destination_node, weight='travel_time')
paths1.append(path)
del paths1[-1]

#Plot the route and street networks
#ox.plot_graph_route(roc_graph, paths1[0], route_linewidth=3, node_size=0, bgcolor='k');
paths1
# Out:
# 2021-09-25 23:02:56 Created edges GeoDataFrame from graph
# 2021-09-25 23:02:57 Created edges GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# []
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:57 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# 2021-09-25 23:02:58 Created nodes GeoDataFrame from graph
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# []

# %%
node_source = []
node_destination = []
X_to = []
Y_to = []
X_from = []
Y_from = []
length = []
travel_time = []
for a, b in zip(path[:-1], path[1:]):
    node_source.append(a)
    node_destination.append(b)
    length.append(round(roc_graph.edges[(a, b, 0)]['length']))
    travel_time.append(round(roc_graph.edges[(a, b, 0)]['travel_time']))
    X_from.append(roc_graph.nodes[a]['x'])
    Y_from.append(roc_graph.nodes[a]['y'])
    X_to.append(roc_graph.nodes[b]['x'])
    Y_to.append(roc_graph.nodes[b]['y'])
