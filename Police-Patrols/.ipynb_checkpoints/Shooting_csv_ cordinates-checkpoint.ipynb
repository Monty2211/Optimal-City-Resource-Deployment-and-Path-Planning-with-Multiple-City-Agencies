# %%
import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd
from geopy import distance
import requests
import json
import datetime
import math
import itertools
import numpy as np
import networkx as nx
import plotly.graph_objects as go
from pulp import *
import seaborn as sn
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %%
shooting_cords = pd.read_csv('Shootings.csv')

# %%
shooting_cords
# Out:
#              X          Y                                ID Case_Number  \
# 0   -77.607990  43.183680  d981912bde17ff11baeec440d2962c55   20-180265
# 1   -77.643147  43.141723  9aed9ae5ee7f83638ee33ccff49cf6b9   20-180404
# 2   -77.611200  43.178448  b0c3f83c934aeea9486ccc2362e0cee6   20-179396
# 3   -77.613357  43.168276  b83cd8b57bb9048cca4830620cbfab07   20-179526
# 4   -77.589725  43.181775  42bb767348c1f8a5e4c085b67ab14732   20-177327
# ..         ...        ...                               ...         ...
# 192 -77.603529  43.186527  25baf3637287b913da75ce7a82c02e76   20-248542
# 193 -77.638011  43.177847  e7e65cbf4cbea4fb5a4b84213e4bff7c   20-247120
# 194 -77.580387  43.163797  f9fc4e2caadd80ba41912e99a4198db3   20-247753
# 195 -77.584300  43.177547  756cd79a8fb43560d781eb216e430d4d   20-246912
# 196 -77.629139  43.151774  1f67441c2eae1d31776b1c961eb74d82   20-245631
#
#                   Address           Occurred_Date  Occurred_Month  \
# ...

# %%
shooting_lat=shooting_cords['Latitude']

# %%
shooting_lat
# Out:
# 0      43.183680
# 1      43.141723
# 2      43.178448
# 3      43.168276
# 4      43.181775
#          ...
# 192    43.186527
# 193    43.177847
# 194    43.163797
# 195    43.177547
# 196    43.151774
# Name: Latitude, Length: 197, dtype: float64

# %%
shooting_long=shooting_cords['Longitude']

# %%
shooting_long
# Out:
# 0     -77.607990
# 1     -77.643147
# 2     -77.611200
# 3     -77.613357
# 4     -77.589725
#          ...
# 192   -77.603529
# 193   -77.638011
# 194   -77.580387
# 195   -77.584300
# 196   -77.629139
# Name: Longitude, Length: 197, dtype: float64

# %%
shooting_lat_long=shooting_cords[['Latitude','Longitude']]

# %%
shooting_lat_long
# Out:
#       Latitude  Longitude
# 0    43.183680 -77.607990
# 1    43.141723 -77.643147
# 2    43.178448 -77.611200
# 3    43.168276 -77.613357
# 4    43.181775 -77.589725
# ..         ...        ...
# 192  43.186527 -77.603529
# 193  43.177847 -77.638011
# 194  43.163797 -77.580387
# 195  43.177547 -77.584300
# 196  43.151774 -77.629139
#
# [197 rows x 2 columns]

# %%
G = ox.graph_from_place('Rochester, NY, USA', network_type='drive_service')
# Out:
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %%
import plotly.express as px
import pandas as pd


fig = px.scatter_geo(shooting_lat_long,lat='Latitude',lon='Longitude')
fig.update_layout(title = 'World Map', title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="a6ec2ab9-cacc-42d8-8dd3-e8c6c5d8889f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6ec2ab9-cacc-42d8-8dd3-e8c6c5d8889f")) {                    Plotly.newPlot(                        "a6ec2ab9-cacc-42d8-8dd3-e8c6c5d8889f",                        [{"geo":"geo","hovertemplate":"Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[43.1836795360001,43.141723401,43.1784481240001,43.168276184,43.1817751680001,43.1817751680001,43.1265908730001,43.1461682390001,43.169300143,43.179133139,43.179133139,43.172693387,43.181900602,43.1743530630001,43.1433883,43.1544642540001,43.156761799,43.1674965030001,43.1426986170001,43.163456888,43.1669565760001,43.159657866,43.1495552480001,43.1432301900001,43.1597051790001
# ...

# %%
def create_rochester_graph(loc, dist, transport_mode, loc_type="address"):
    """Transport mode = ‘walk’, ‘bike’, ‘drive’, ‘drive_service’, ‘all’, ‘all_private’, ‘none’"""
    if loc_type == "address":
        roc_graph = ox.graph_from_address(loc, dist=dist, network_type=transport_mode)
    elif loc_type == "points":
        roc_graph = ox.graph_from_point(loc, dist=dist, network_type=transport_mode )
    return roc_graph

# %%
roc_graph = create_rochester_graph('Rochester', 2500, 'drive_service')
ox.plot_graph(roc_graph)
# Out:
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning:
#
# Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning:
#
# Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#
# /Users/rochelleallan/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning:
#
# Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
import matplotlib.pyplot as plt
plt.scatter(x=shooting_cords['Longitude'], y=shooting_cords['Latitude'])
plt.show()

# %%
import folium
map1 = folium.Map(
    location=[43.151774, -77.629139],
    tiles='cartodbpositron',
    zoom_start=12,
)
shooting_cords.apply(lambda row:folium.CircleMarker(location=[row["Latitude"], row["Longitude"]]).add_to(map1), axis=1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
shooting_cords
# Out:
#              X          Y                                ID Case_Number  \
# 0   -77.607990  43.183680  d981912bde17ff11baeec440d2962c55   20-180265
# 1   -77.643147  43.141723  9aed9ae5ee7f83638ee33ccff49cf6b9   20-180404
# 2   -77.611200  43.178448  b0c3f83c934aeea9486ccc2362e0cee6   20-179396
# 3   -77.613357  43.168276  b83cd8b57bb9048cca4830620cbfab07   20-179526
# 4   -77.589725  43.181775  42bb767348c1f8a5e4c085b67ab14732   20-177327
# ..         ...        ...                               ...         ...
# 192 -77.603529  43.186527  25baf3637287b913da75ce7a82c02e76   20-248542
# 193 -77.638011  43.177847  e7e65cbf4cbea4fb5a4b84213e4bff7c   20-247120
# 194 -77.580387  43.163797  f9fc4e2caadd80ba41912e99a4198db3   20-247753
# 195 -77.584300  43.177547  756cd79a8fb43560d781eb216e430d4d   20-246912
# 196 -77.629139  43.151774  1f67441c2eae1d31776b1c961eb74d82   20-245631
#
#                   Address           Occurred_Date  Occurred_Month  \
# ...

# %%
from IPython.display import Image
Image(filename = "Shooting_sites.png", width = 600, height = 300)

# %%
from IPython.display import Image
Image(filename = "Rochester_confirmed.png", width = 600, height = 300)
