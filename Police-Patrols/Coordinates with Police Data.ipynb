# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
latitude, longitude,= [],[]
with open('Shootings.csv') as csvfile:
    file= csv.DictReader(csvfile,delimiter=',')
    for cords in file:
        latitude.append(float(data['Latitude']))
        longitude.append(float(data['Longitude']))

# %%
#In degrees, zoom from cordinates 
zoom_scale = 0

# %%
# The bound box to represent bounds of the map saved in image
boundbox = [np.min(latitude)-zoom_scale,np.max(latitude)+zoom_scale,\
        np.min(longitude)-zoom_scale,np.max(longitude)+zoom_scale]

# %%
plt.figure(figsize=(10,6))
# Define the projection, scale, the corners of the map, and the resolution.
roc_map = Basemap(projection='merc',llcrnrlat=bbox[0],urcrnrlat=bbox[1],\
            llcrnrlon=bbox[2],urcrnrlon=bbox[3],lat_ts=10,resolution='h')

# %%
# Coastlines and continent colours
roc_map.drawcoastlines()
roc_map.fillcontinents(color='yellow',lake_color='aqua')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-2b8b74a0f0ac> in <module>
#       1 # Draw coastlines and fill continents and water with color
# ----> 2 roc_map.drawcoastlines()
#       3 roc_map.fillcontinents(color='yellow',lake_color='aqua')
#
# ~/anaconda3/lib/python3.8/site-packages/mpl_toolkits/basemap/__init__.py in drawcoastlines(self, linewidth, linestyle, color, antialiased, ax, zorder)
#    1857         # get current axes instance (if none specified).
#    1858         ax = ax or self._check_ax()
# -> 1859         coastlines = LineCollection(self.coastsegs,antialiaseds=(antialiased,))
#    1860         coastlines.set_color(color)
#    1861         coastlines.set_linestyle(linestyle)
#
# ...

# %%
# paralles, meridians and colors to sepe
roc_map.drawparallels(np.arange(bbox[0],bbox[1],(bbox[1]-bbox[0])/5),labels=[1,0,0,0])
roc_map.drawmeridians(np.arange(bbox[2],bbox[3],(bbox[3]-bbox[2])/5),labels=[0,0,0,1],rotation=45)
roc_map.drawmapboundary(fill_color='aqua')

# %%
# build and plot coordinates onto map
x,y = m(lons,lats)
roc_map.plot(x,y,'r*',markersize=5)
plt.title("Rochester map for Police Patrolling")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-160-0dc63be2eef9> in <module>
#       1 # build and plot coordinates onto map
#       2 x,y = m(lons,lats)
# ----> 3 roc_map.plot(x,y,'r*',markersize=5)
#       4 plt.title("Rochester map for Police Patrolling")
#       5 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/mpl_toolkits/basemap/__init__.py in with_transform(self, x, y, *args, **kwargs)
#     567             # convert lat/lon coords to map projection coords.
#     568             x, y = self(x,y)
# --> 569         return plotfunc(self,x,y,*args,**kwargs)
#     570     return with_transform
#     571
#
# ~/anaconda3/lib/python3.8/site-packages/mpl_toolkits/basemap/__init__.py in plot(self, *args, **kwargs)
#    3297         self.set_axes_limits(ax=ax)
#    3298         # clip to map limbs
# -> 3299         ret,c = self._cliplimb(ax,ret)
# ...
