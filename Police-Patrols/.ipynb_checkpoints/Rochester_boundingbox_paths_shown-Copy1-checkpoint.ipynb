# %%
import osmnx as ox
import matplotlib.pyplot as plt 
import osmnx as ox
import pandas as pd
from geopy import distance
import requests # to call the openmap/google apis
import json
import datetime
import math
import itertools
import numpy as np
import networkx as nx
import osmnx as ox
from shapely.geometry import Point, LineString
import plotly_express as px
import pandas as pd
import geopandas as gpd

# %%
ox.config(use_cache=True, log_console=True) #For debugging
# Out:
# 2021-09-24 22:35:48 Configured OSMnx 1.1.1
# 2021-09-24 22:35:48 HTTP response caching is on

# %%
def create_rochester_graph(loc, dist, transport_mode, loc_type="address"):
    """Transport mode = ‘walk’, ‘bike’, ‘drive’, ‘drive_service’, ‘all’, ‘all_private’, ‘none’"""
    if loc_type == "address":
        roc_graph = ox.graph_from_address(loc, dist=dist, network_type=transport_mode)
    elif loc_type == "points":
        roc_graph = ox.graph_from_point(loc, dist=dist, network_type=transport_mode )
    return roc_graph

# %%
roc_graph = create_rochester_graph('Rochester', 10000, 'drive_service')
ox.plot_graph(roc_graph)
# Out:
# 2021-09-24 23:19:09 Retrieved response from cache file "cache/122893a9c77ace471118d977e4561a9f45117fb9.json"
# 2021-09-24 23:19:09 Geocoded "Rochester" to (43.157285, -77.615214)
# 2021-09-24 23:19:09 Created bbox 10000 m from (43.157285, -77.615214): 43.24721703354929,43.06735296645071,-77.49193140745446,-77.73849659254553
# 2021-09-24 23:19:10 Projected GeoDataFrame to +proj=utm +zone=18 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-09-24 23:19:10 Projected GeoDataFrame to epsg:4326
# 2021-09-24 23:19:10 Projected GeoDataFrame to +proj=utm +zone=18 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-09-24 23:19:10 Projected GeoDataFrame to epsg:4326
# 2021-09-24 23:19:10 Requesting data within polygon from API in 1 request(s)
# 2021-09-24 23:19:11 Resolved overpass-api.de to 178.63.48.217
# 2021-09-24 23:19:11 Pausing 0 seconds before making HTTP POST request
# 2021-09-24 23:19:11 Post https://overpass-api.de/api/interpreter?data=%5Bout%3Ajson%5D%5Btimeout%3A180%5D%3B%28way%5B%22highway%22%5D%5B%22area%22%21~%22yes%22%5D%5B%22access%22%21~%22private%22%5D%5B%22highway%22%21~%22abandoned%7Cbridleway%7Cbus_guideway%7Cconstruction%7Ccorridor%7Ccycleway%7Celevator%7Cescalator%7Cfootway%7Cpath%7Cpedestrian%7Cplanned%7Cplatform%7Cproposed%7Craceway%7Csteps%7Ctrack%22%5D%5B%22motor_vehicle%22%21~%22no%22%5D%5B%22motorcar%22%21~%22no%22%5D%5B%22service%22%21~%22emergency_access%7Cparking%7Cparking_aisle%7Cprivate%22%5D%28poly%3A%2743.067353+-77.744634+43.247217+-77.744652+43.247657+-77.744622+43.248094+-77.744534+43.248522+-77.744388+43.248937+-77.744185+43.249336+-77.743927+43.249715+-77.743617+43.250069+-77.743258+43.250396+-77.742853+43.250693+-77.742406+43.250956+-77.741921+43.251183+-77.741404+43.251372+-77.740859+43.251521+-77.740291+43.251629+-77.739705+43.251694+-77.739108+43.251717+-77.738506+43.251717+-77.491922+43.251695+-77.491320+43.251630+-77.490723+43.251522+-77.490137+
# 2021-09-24 23:20:58 graph_from_bbox returned graph with 30303 nodes and 77297 edges
# 2021-09-24 23:20:58 graph_from_point returned graph with 30303 nodes and 77297 edges
# 2021-09-24 23:20:58 graph_from_address returned graph with 30303 nodes and 77297 edges
# 2021-09-24 23:20:58 Begin plotting the graph...
# 2021-09-24 23:21:10 Created edges GeoDataFrame from graph
# 2021-09-24 23:21:29 Created nodes GeoDataFrame from graph
# 2021-09-24 23:21:42 Finished plotting the graph
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
roc_df = pd.read_csv("BoxAreaRochester.csv")

# %%
roc_df
# Out:
#     Unnamed: 0   Locations   Latitude  Longitude
# 0            0   212629561  43.137407 -77.598233
# 1            1   212629563  43.136945 -77.598493
# 2            2   212676319  43.134420 -77.602399
# 3            3   212769675  43.137430 -77.603818
# 4            4   212769677  43.136636 -77.601178
# 5            5   212769679  43.135769 -77.598343
# 6            6   212782003  43.138067 -77.600400
# 7            7   212782005  43.137609 -77.598897
# 8            8   212813912  43.138074 -77.603483
# 9            9   212813914  43.137271 -77.600835
# 10          10   212813917  43.136415 -77.597977
# 11          11   212872572  43.136007 -77.601529
# 12          12   212872575  43.135133 -77.598700
# 13          13   212873619  43.135553 -77.598466
# 14          14   212904187  43.134500 -77.599068
# 15          15   212908698  43.135347 -77.601880
# 16          16   212908725  43.133946 -77.603805
# 17          17  2653824864  43.136355 -77.598010
# 18          18  8077196381  43.137160 -77.598372

# %%
routes =[[(11, 4),
  (4, 7),
  (7, 0),
  (0, 18),
  (18, 1),
  (1, 6),
  (6, 9),
  (9, 8),
  (8, 3),
  (3, 11)],
 [(11, 15),
  (15, 2),
  (2, 16),
  (16, 14),
  (14, 12),
  (12, 13),
  (13, 5),
  (5, 17),
  (17, 10),
  (10, 11)]]

# %%
routes[0]
# Out:
# [(11, 4),
#  (4, 7),
#  (7, 0),
#  (0, 18),
#  (18, 1),
#  (1, 6),
#  (6, 9),
#  (9, 8),
#  (8, 3),
#  (3, 11)]

# %%
order1 = [11,4,7,0,18,1,6,9,8,3,11]
order2 = [11,15,2,16,14,12,13,5,17,10,11]

# %%
df3 = pd.DataFrame()
for i in order1:
    df3 = df3.append(roc_df.loc[i])

# %%
df4 = pd.DataFrame()
for i in order1:
    df4 = df4.append(roc_df.loc[i])

# %%
df3
# Out:
#     Unnamed: 0     Locations   Latitude  Longitude
# 11        11.0  2.128726e+08  43.136007 -77.601529
# 4          4.0  2.127697e+08  43.136636 -77.601178
# 7          7.0  2.127820e+08  43.137609 -77.598897
# 0          0.0  2.126296e+08  43.137407 -77.598233
# 18        18.0  8.077196e+09  43.137160 -77.598372
# 1          1.0  2.126296e+08  43.136945 -77.598493
# 6          6.0  2.127820e+08  43.138067 -77.600400
# 9          9.0  2.128139e+08  43.137271 -77.600835
# 8          8.0  2.128139e+08  43.138074 -77.603483
# 3          3.0  2.127697e+08  43.137430 -77.603818
# 11        11.0  2.128726e+08  43.136007 -77.601529

# %%
df3.reset_index(inplace = True)
df4.reset_index(inplace = True)

# %%
loc=[]
for i in df3.index:
    loc.append(int(df3.loc[i]['Locations']))
loc
# Out:
# [212872572,
#  212769677,
#  212782005,
#  212629561,
#  8077196381,
#  212629563,
#  212782003,
#  212813914,
#  212813912,
#  212769675,
#  212872572]

# %%
roc_graph = ox.add_edge_speeds(roc_graph) #Impute
roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
#Plot the route and street networks
ox.plot_graph_route(roc_graph, loc, route_linewidth=3, node_size=0, bgcolor='k');
# Out:
# 2021-09-24 23:22:45 Created edges GeoDataFrame from graph
# 2021-09-24 23:22:54 Created edges GeoDataFrame from graph
# 2021-09-24 23:22:55 Begin plotting the graph...
# 2021-09-24 23:23:03 Created edges GeoDataFrame from graph
# 2021-09-24 23:23:21 Finished plotting the graph
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/0f/0wx77bhd2sl15rhs858yxhtc0000gn/T/ipykernel_16126/53626020.py in <module>
#       2 roc_graph = ox.add_edge_travel_times(roc_graph) #Travel time
#       3 #Plot the route and street networks
# ----> 4 ox.plot_graph_route(roc_graph, loc, route_linewidth=3, node_size=0, bgcolor='k');
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/plot.py in plot_graph_route(G, route, route_color, route_linewidth, route_alpha, orig_dest_size, ax, **pg_kwargs)
#     301     for u, v in zip(route[:-1], route[1:]):
#     302         # if there are parallel edges, select the shortest in length
# --> 303         data = min(G.get_edge_data(u, v).values(), key=lambda d: d["length"])
#     304         if "geometry" in data:
#     305             # if geometry attribute exists, add all its coords to list
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
ox.plot_graph(roc_graph)

# %%
roc_graph[8077196381]
# Out:
# AdjacencyView({212629563: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 25.844, 'speed_kph': 42.6, 'travel_time': 2.2}}, 212629561: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691, 'speed_kph': 42.6, 'travel_time': 2.5}}})

# %%
loc=[]
for i in df3.index:
    print(roc_graph[df3.loc[i]['Locations']])
#roc_graph[df3.loc[0]['Locations']]
# Out:
# {212872575: {0: {'osmid': 20132618, 'name': 'Mulberry Street', 'highway': 'residential', 'oneway': False, 'length': 249.314, 'speed_kph': 40.7, 'travel_time': 22.1}}, 212872569: {0: {'osmid': 20132618, 'name': 'Mulberry Street', 'highway': 'residential', 'oneway': False, 'length': 231.025, 'speed_kph': 40.7, 'travel_time': 20.4}}, 212908698: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 78.722, 'speed_kph': 40.7, 'travel_time': 7.0}}, 212769677: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.518, 'speed_kph': 40.7, 'travel_time': 6.7}}}
# {212769675: {0: {'osmid': 20123307, 'name': 'Crawford Street', 'highway': 'residential', 'oneway': False, 'length': 231.694, 'speed_kph': 40.7, 'travel_time': 20.5}}, 212872572: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.518, 'speed_kph': 40.7, 'travel_time': 6.7}}, 212813914: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.896, 'speed_kph': 40.7, 'travel_time': 6.7}}, 212769679: {0: {'osmid': 20123307, 'name': 'Crawford Street', 'highway': 'residential', 'oneway': False, 'length': 249.458, 'geometry': <shapely.geometry.linestring.LineString object at 0x17dd49e50>, 'speed_kph': 40.7, 'travel_time': 22.1}}}
# {212629561: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 58.372, 'speed_kph': 40.7, 'travel_time': 5.2}}, 212782003: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 132.16, 'speed_kph': 40.7, 'travel_time': 11.7}}}
# {8077196381: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691, 'speed_kph': 40.7, 'travel_time': 2.6}}, 212629557: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 115.935, 'speed_kph': 40.7, 'travel_time': 10.3}}, 212782009: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 60.861, 'speed_kph': 40.7, 'travel_time': 5.4}}, 212782005: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 58.372, 'speed_kph': 40.7, 'travel_time': 5.2}}}
# {212629563: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 25.844, 'speed_kph': 40.7, 'travel_time': 2.3}}, 212629561: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691, 'speed_kph': 40.7, 'travel_time': 2.6}}}
# {8077196381: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 25.844, 'speed_kph': 40.7, 'travel_time': 2.3}}}
# {212782005: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 132.16, 'speed_kph': 40.7, 'travel_time': 11.7}}, 212782001: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 233.542, 'speed_kph': 40.7, 'travel_time': 20.7}}, 212908695: {0: {'osmid': 38656179, 'name': 'Meigs Street', 'highway': 'tertiary', 'oneway': False, 'length': 115.685, 'speed_kph': 54.8, 'travel_time': 7.6}}, 212813914: {0: {'osmid': 38656179, 'name': 'Meigs Street', 'highway': 'tertiary', 'oneway': False, 'length': 95.28999999999999, 'geometry': <shapely.geometry.linestring.LineString object at 0x17e1a9100>, 'speed_kph': 54.8, 'travel_time': 6.3}}}
# {212813912: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 232.675, 'speed_kph': 54.8, 'travel_time': 15.3}}, 212769677: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.896, 'speed_kph': 40.7, 'travel_time': 6.7}}, 212813917: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 250.723, 'geometry': <shapely.geometry.linestring.LineString object at 0x17f4216a0>, 'speed_kph': 54.8, 'travel_time': 16.5}}, 212782003: {0: {'osmid': 38656179, 'name': 'Meigs Street', 'highway': 'tertiary', 'oneway': False, 'length': 95.28999999999999, 'geometry': <shapely.geometry.linestring.LineString object at 0x17f421760>, 'speed_kph': 54.8, 'travel_time': 6.3}}}
# {212813914: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 232.675, 'speed_kph': 54.8, 'travel_time': 15.3}}, 212772024: {0: {'osmid': 20127273, 'name': 'Linden Street', 'highway': 'tertiary', 'oneway': False, 'length': 107.719, 'speed_kph': 54.8, 'travel_time': 7.1}}, 212769675: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 76.595, 'speed_kph': 40.7, 'travel_time': 6.8}}, 212782001: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 94.223, 'speed_kph': 40.7, 'travel_time': 8.3}}}
# {212769677: {0: {'osmid': 20123307, 'name': 'Crawford Street', 'highway': 'residential', 'oneway': False, 'length': 231.694, 'speed_kph': 40.7, 'travel_time': 20.5}}, 212872569: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 76.089, 'speed_kph': 40.7, 'travel_time': 6.7}}, 212813912: {0: {'osmid': 20133476, 'name': 'Mount Vernon Avenue', 'highway': 'residential', 'oneway': False, 'length': 76.595, 'speed_kph': 40.7, 'travel_time': 6.8}}}
# {212872575: {0: {'osmid': 20132618, 'name': 'Mulberry Street', 'highway': 'residential', 'oneway': False, 'length': 249.314, 'speed_kph': 40.7, 'travel_time': 22.1}}, 212872569: {0: {'osmid': 20132618, 'name': 'Mulberry Street', 'highway': 'residential', 'oneway': False, 'length': 231.025, 'speed_kph': 40.7, 'travel_time': 20.4}}, 212908698: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 78.722, 'speed_kph': 40.7, 'travel_time': 7.0}}, 212769677: {0: {'osmid': 592148087, 'name': 'Meigs Street', 'highway': 'residential', 'oneway': False, 'length': 75.518, 'speed_kph': 40.7, 'travel_time': 6.7}}}

# %%
roc_graph[212629561]
# Out:
# AdjacencyView({8077196381: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 29.691, 'speed_kph': 40.7, 'travel_time': 2.6}}, 212629557: {0: {'osmid': 20112053, 'name': 'Seager Street', 'highway': 'residential', 'oneway': False, 'length': 115.935, 'speed_kph': 40.7, 'travel_time': 10.3}}, 212782009: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 60.861, 'speed_kph': 40.7, 'travel_time': 5.4}}, 212782005: {0: {'osmid': 20124517, 'name': 'Benton Street', 'highway': 'residential', 'oneway': False, 'length': 58.372, 'speed_kph': 40.7, 'travel_time': 5.2}}})
