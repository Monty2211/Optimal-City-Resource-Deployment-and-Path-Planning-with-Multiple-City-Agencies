# %%
import osmnx as ox
city = ox.geocode_to_gdf('Raleigh, NC, USA')
ax = ox.project_gdf(city).plot()
_ = ax.axis('off')

# %%
G = ox.graph_from_place('Raleigh, NC, USA', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
import matplotlib.pyplot as plt 
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
ox.plot.plot_graph(G, bgcolor='#FFFFFF', node_color=colors[0], edge_color='lightgray', node_size=5)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
# define a bounding box in DC
north, south, east, west = 35.581304,35.585510,-78.795250,-78.803511

# %%
# create network from that bounding box
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
ox.plot.plot_graph(G, bgcolor='#FFFFFF', node_color=colors[0], edge_color='lightgray', node_size=5)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
G

# %%
G.graph
# Out:
# {'created_date': '2021-09-12 11:06:54',
#  'created_with': 'OSMnx 1.1.1',
#  'crs': 'epsg:4326',
#  'simplified': True}

# %%
print(G.graph)
# Out:
# {'created_date': '2021-09-12 11:06:54', 'created_with': 'OSMnx 1.1.1', 'crs': 'epsg:4326', 'simplified': True}

# %%
G.nodes
# Out:
# NodeView((195393177, 195416226, 195438253, 195438255, 195438256, 195438631, 195438633, 195447516, 195447518, 195447520, 195456444, 195471151, 195475306, 195475310, 195500922, 195522045, 195567222, 195594836, 195594842, 195602233, 195631802, 195631803, 195652964, 1455684307, 4291074049, 6359366478, 6359366687, 6359366711, 6538261507, 6538261513, 6538261514, 6548479355, 7463971107, 7463971111, 7472627041, 7472627042, 7732555375, 7732555376, 7738633578, 7738633583, 7738713985, 8428931563, 8428931567, 8505787012, 8505787015, 8562827015, 8562849427, 8562849428, 8562849429, 8739204974, 8739204975, 8739204976, 8739204978))

# %%
G.nodes[195393177]
# Out:
# {'y': 35.5820663, 'x': -78.8021196, 'street_count': 1}

# %%
G.nodes[8739204976]
# Out:
# {'y': 35.5819707, 'x': -78.7984249, 'street_count': 3}

# %%
for i in G.nodes:
    print(i)
# Out:
# 195393177
# 195416226
# 195438253
# 195438255
# 195438256
# 195438631
# 195438633
# 195447516
# 195447518
# 195447520
# 195456444
# 195471151
# 195475306
# 195475310
# 195500922
# 195522045
# 195567222
# 195594836
# 195594842
# 195602233
# 195631802
# 195631803
# 195652964
# 1455684307
# 4291074049
# 6359366478
# 6359366687
# 6359366711
# 6538261507
# 6538261513
# 6538261514
# 6548479355
# 7463971107
# 7463971111
# 7472627041
# 7472627042
# 7732555375
# 7732555376
# 7738633578
# 7738633583
# 7738713985
# 8428931563
# 8428931567
# 8505787012
# 8505787015
# 8562827015
# 8562849427
# 8562849428
# 8562849429
# 8739204974
# 8739204975
# 8739204976
# 8739204978
